# %% [markdown]
# # [Data Visualization](https://www.kaggle.com/learn/data-visualization)
# ## Setup

# %%
import pandas as pd
pd.plotting.register_matplotlib_converters()
import matplotlib.pyplot as plt
# %matplotlib inline
import seaborn as sns

# Set up code checking
print("Setup Complete")
# Out:
# Setup Complete

# %% [markdown]
# ## Line chart

# %% [markdown]
# ### Plot entire dataset
# Load data

# %%
# Path of the file to read
fifa_filepath = "data/fifa.csv"

# Read the file into a variable fifa_data
fifa_data = pd.read_csv(fifa_filepath, index_col="Date", parse_dates=True)

fifa_data.head()
# Out:
#              ARG  BRA   ESP   FRA  GER  ITA
# Date
# 1993-08-08   5.0  8.0  13.0  12.0  1.0  2.0
# 1993-09-23  12.0  1.0  14.0   7.0  5.0  2.0
# 1993-10-22   9.0  1.0   7.0  14.0  4.0  3.0
# 1993-11-19   9.0  4.0   7.0  15.0  3.0  1.0
# 1993-12-23   8.0  3.0   5.0  15.0  1.0  2.0

# %% [markdown]
# Plot the data

# %%
# Set the width and height of the figure
plt.figure(figsize=(16,6))

# Line chart showing how FIFA rankings evolved over time
sns.lineplot(data=fifa_data)   # sns.relplot(fifa_data, kind='line')
# Out:
# <Axes: xlabel='Date'>

# %% [markdown]
# ### Set title of plot

# %%
spotify_data = pd.read_csv("data/spotify.csv", index_col="Date", parse_dates=True)

display(spotify_data.head())

# Set the width and height of the figure
plt.figure(figsize=(14,6))

# Add title
plt.title("Daily Global Streams of Popular Songs in 2017-2018")

# Line chart showing daily global streams of each song 
sns.lineplot(data=spotify_data)
# Out:
#             Shape of You  Despacito  Something Just Like This  HUMBLE.  \
# Date
# 2017-01-06      12287078        NaN                       NaN      NaN
# 2017-01-07      13190270        NaN                       NaN      NaN
# 2017-01-08      13099919        NaN                       NaN      NaN
# 2017-01-09      14506351        NaN                       NaN      NaN
# 2017-01-10      14275628        NaN                       NaN      NaN
#
#             Unforgettable
# Date
# 2017-01-06            NaN
# 2017-01-07            NaN
# 2017-01-08            NaN
# 2017-01-09            NaN
# 2017-01-10            NaN
# <Axes: title={'center': 'Daily Global Streams of Popular Songs in 2017-2018'}, xlabel='Date'>

# %% [markdown]
# ### Plot a subset of the data
# List of the columns of spotify_data dataframe:

# %%
list(spotify_data.columns)
# Out:
# ['Shape of You',
#  'Despacito',
#  'Something Just Like This',
#  'HUMBLE.',
#  'Unforgettable']

# %% [markdown]
# Plot the lines corresponding to the first two columns.

# %%
# Set the width and height of the figure
plt.figure(figsize=(14,6))

# Add title
plt.title("Daily Global Streams of Popular Songs in 2017-2018")

# Line chart showing daily global streams of 'Shape of You'
sns.lineplot(data=spotify_data['Shape of You'], label="Shape of You")

# Line chart showing daily global streams of 'Despacito'
sns.lineplot(data=spotify_data['Despacito'], label="Despacito")

# Add label for horizontal axis
plt.xlabel("Date")
# Out:
# Text(0.5, 0, 'Date')

# %% [markdown]
# ## Bar Chart

# %% [markdown]
# ### Load data

# %%
# Path of the file to read
flight_filepath = "data/flight_delays.csv"

# Read the file into a variable flight_data
flight_data = pd.read_csv(flight_filepath, index_col="Month")

# Print the data
flight_data
# Out:
#              AA        AS         B6        DL         EV         F9  \
# Month
# 1      6.955843 -0.320888   7.347281 -2.043847   8.537497  18.357238
# 2      7.530204 -0.782923  18.657673  5.614745  10.417236  27.424179
# 3      6.693587 -0.544731  10.741317  2.077965   6.730101  20.074855
# 4      4.931778 -3.009003   2.780105  0.083343   4.821253  12.640440
# 5      5.173878 -1.716398  -0.709019  0.149333   7.724290  13.007554
# 6      8.191017 -0.220621   5.047155  4.419594  13.952793  19.712951
# 7      3.870440  0.377408   5.841454  1.204862   6.926421  14.464543
# 8      3.193907  2.503899   9.280950  0.653114   5.154422   9.175737
# 9     -1.432732 -1.813800   3.539154 -3.703377   0.851062   0.978460
# 10    -0.580930 -2.993617   3.676787 -5.011516   2.303760   0.082127
# 11     0.772630 -1.916516   1.418299 -3.175414   4.415930  11.164527
# 12     4.149684 -1.846681  13.839290  2.504595   6.685176   9.346221
#
# ...

# %% [markdown]
# ### Plot bar chart

# %%
# Set the width and height of the figure
plt.figure(figsize=(10,6))

# Add title
plt.title("Average Arrival Delay for Spirit Airlines Flights, by Month")

# Bar chart showing average arrival delay for Spirit Airlines flights by month
sns.barplot(
    x=flight_data.index,   # the horizontal axis
    y=flight_data['NK']    # the height of each bar
)

# Add label for vertical axis
plt.ylabel("Arrival delay (in minutes)")
# Out:
# Text(0, 0.5, 'Arrival delay (in minutes)')

# %% [markdown]
# > Note: You must select the indexing column with flight_data.index; flight_data['Month'] will return an error.

# %% [markdown]
# ## Heatmap
#
# * method: [sns.heatmap()](https://seaborn.pydata.org/generated/seaborn.heatmap.html#seaborn-heatmap)

# %%
# Set the width and height of the figure
plt.figure(figsize=(14,7))

# Add title
plt.title("Average Arrival Delay for Each Airline, by Month")

# Heatmap showing average arrival delay for each airline by month
sns.heatmap(
    data=flight_data, 
    annot=True,        # show number values in each cell
    linewidth=.5,
    fmt=".1f",         # String formatting code to use when adding annotations.
    cmap="YlOrBr",     # Set color palettes. 
)

# Add label for horizontal axis
plt.xlabel("Airline")
# Out:
# Text(0.5, 47.7222222222222, 'Airline')

# %% [markdown]
# See avalable [color palettes](https://seaborn.pydata.org/tutorial/color_palettes.html#sequential-color-brewer-palettes) here.

# %% [markdown]
# ## Scatter Plots

# %%
# Path of the file to read
insurance_filepath = "data/insurance.csv"

# Read the file into a variable insurance_data
insurance_data = pd.read_csv(insurance_filepath)

insurance_data.head()
# Out:
#    age     sex     bmi  children smoker     region      charges
# 0   19  female  27.900         0    yes  southwest  16884.92400
# 1   18    male  33.770         1     no  southeast   1725.55230
# 2   28    male  33.000         3     no  southeast   4449.46200
# 3   33    male  22.705         0     no  northwest  21984.47061
# 4   32    male  28.880         0     no  northwest   3866.85520

# %% [markdown]
# ### Scatter Plot
# Usually, scatter plots are used to highlight the relationship between two continuous variables (like "bmi" and "charges").
#
# We plot scatter chart with method: [sns.scatterplot()](https://seaborn.pydata.org/generated/seaborn.scatterplot.html)

# %%
sns.scatterplot(
    data=insurance_data,
    x='bmi', 
    y='charges',
    hue="smoker",   # map smoker value to the color of the points
    style="smoker", # produce points with different markers
)
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %% [markdown]
# ### Plot with a linear regression fit

# %% [markdown]
# The scatterplot above suggests that body mass index (BMI) and insurance charges are positively correlated, where customers with higher BMI typically also tend to pay more in insurance costs.
#
# To check the strength of this relationship, we use `sns.regplot()` to add a regression.

# %%
sns.regplot(
   data=insurance_data,
    x='bmi', 
    y='charges',
    order=1,        # If order is greater than 1, use a polynomial regression
)
# Out:
# <Axes: xlabel='bmi', ylabel='charges'>

# %% [markdown]
# ### Plot with more linear regression lines

# %% [markdown]
# The scatter plot with `hue="smoker"` paramter shows that smokers pays more than non-smokers with increasing BMI.
#
# To further emphasize this fact, we can use the **[sns.lmplot()](https://seaborn.pydata.org/generated/seaborn.lmplot.html)** method to add two regression lines, corresponding to smokers and nonsmokers. (You'll notice that the regression line for smokers has a much steeper slope, relative to the line for nonsmokers!)

# %%
sns.lmplot(
    data=insurance_data,
    x='bmi', 
    y='charges',
    order=1,        # If order is greater than 1, use a polynomial regression
    hue="smoker",
)

# %% [markdown]
# ### Categorical scatter plot

# %% [markdown]
# Categorical scatter plot used to visualize the relationship between two categorical variables. Unlike numerical scatter plots, which display the relationship between two numerical variables, categorical scatter plots represent the distribution of data points for each category of the variables.

# %%
sns.swarmplot(
    data=insurance_data,
    x='smoker',
    y='charges'
)
# Out:
# /usr/local/lib/python3.11/site-packages/seaborn/categorical.py:3399: UserWarning: 37.4% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)
# <Axes: xlabel='smoker', ylabel='charges'>
# /usr/local/lib/python3.11/site-packages/seaborn/categorical.py:3399: UserWarning: 60.8% of the points cannot be placed; you may want to decrease the size of the markers or use stripplot.
#   warnings.warn(msg, UserWarning)

# %% [markdown]
# This plot shows us that:
#
# * on average, non-smokers are charged less than smokers, and
# * the customers who pay the most are smokers; whereas the customers who pay the least are non-smokers.

# %% [markdown]
# ## Pie Chart

# %%
insurance_data.describe(include="object").T

category_features = insurance_data\
    .select_dtypes(include=['object'])\
    .columns.\
    tolist()

for feature in category_features:
    aggregation = insurance_data[feature].value_counts()
    print(aggregation, '\n\n')
    plt.pie(x=aggregation, labels=aggregation.index, autopct='%1.2f%%', startangle=90)
    plt.show()
# Out:
# sex
# male      676
# female    662
# Name: count, dtype: int64
# smoker
# no     1064
# yes     274
# Name: count, dtype: int64
# region
# southeast    364
# southwest    325
# northwest    325
# northeast    324
# Name: count, dtype: int64

# %% [markdown]
# ## Distributions

# %%
# Path of the file to read
iris_filepath = "data/iris.csv"

# Read the file into a variable iris_data
iris_data = pd.read_csv(iris_filepath, index_col="Id")

# Print the first 5 rows of the data
iris_data.head()
# Out:
#     Sepal Length (cm)  Sepal Width (cm)  Petal Length (cm)  Petal Width (cm)  \
# Id
# 1                 5.1               3.5                1.4               0.2
# 2                 4.9               3.0                1.4               0.2
# 3                 4.7               3.2                1.3               0.2
# 4                 4.6               3.1                1.5               0.2
# 5                 5.0               3.6                1.4               0.2
#
#         Species
# Id
# 1   Iris-setosa
# 2   Iris-setosa
# 3   Iris-setosa
# 4   Iris-setosa
# 5   Iris-setosa

# %% [markdown]
# ### Histograms

# %%
# Histogram 
sns.histplot(
    data=iris_data, 
    x='Petal Length (cm)'
)
# Out:
# <Axes: xlabel='Petal Length (cm)', ylabel='Count'>

# %% [markdown]
# ### Density plots
# `Kernel density estimate (KDE)` plot is a smoothed histogram.

# %%
# KDE plot 
sns.kdeplot(
    data=iris_data,
    x='Petal Length (cm)', 
    fill=True,              # fill a color in the area below the curve
)
# Out:
# <Axes: xlabel='Petal Length (cm)', ylabel='Density'>

# %% [markdown]
# In fact, `sns.histplot()` can plat the kde too.
# Add a kernel density estimate to smooth the histogram, providing complementary information about the shape of the distribution:

# %%
# Histogram 
sns.histplot(
    data=iris_data, 
    x='Petal Length (cm)',
    kde=True,
)
# Out:
# <Axes: xlabel='Petal Length (cm)', ylabel='Count'>

# %% [markdown]
# ### 2D KDE plots

# %% [markdown]
# We can create a two-dimensional (2D) KDE plot with the `sns.jointplot()` command.
#
# In the plot below, the color-coding shows us how likely we are to see different combinations of sepal width and petal length, where darker parts of the figure are more likely.

# %%
# 2D KDE plot
sns.jointplot(
    data=iris_data,
    x='Petal Length (cm)', 
    y='Sepal Width (cm)', 
    kind="kde",
    fill=True, thresh=0, cmap='Blues' # plot with color mapping
)

# %% [markdown]
# In addition to the 2D KDE plot in the center, the curves at the top and right of the figure are KDE plots too:
#
# * The top KDE plot for the data on the x-axis (`Petal Length (cm)`), and
# * The right KDE plot for the data on the y-axis (`Sepal Width (cm)`).

# %% [markdown]
# ### Color-coded plots

# %% [markdown]
# We will create plots to understand differences between the species.
#
# By adding `hue='Species'`, the histogram color coded on species.

# %%
# Histogram 
sns.histplot(
    data=iris_data, 
    x='Petal Length (cm)',
    kde=True,
    hue='Species',  # color colded on Species categorial
)
# Out:
# <Axes: xlabel='Petal Length (cm)', ylabel='Count'>

# %% [markdown]
# We can also create a KDE plot for each species by using `sns.kdeplot` (as above).

# %%
# KDE plot 
sns.kdeplot(
    data=iris_data,
    x='Petal Length (cm)', 
    fill=True,              # fill a color in the area below the curve
    hue='Species',          # color colded on Species categorial
)
# Out:
# <Axes: xlabel='Petal Length (cm)', ylabel='Density'>

# %% [markdown]
# See the diagram above, we might be able to classify any iris plant as Iris setosa just by looking at the petal length:
# * If the petal length of an iris flower is less than 2 cm, it's most likely to be Iris setosa!

# %% [markdown]
# ## Change style

# %%
# Try tp change the style of the figure to the "dark" theme
sns.set_style("white") # style: dict, or one of {darkgrid, whitegrid, dark, white, ticks}

# KDE plot 
sns.kdeplot(
    data=iris_data,
    x='Petal Length (cm)', 
    fill=True,              # fill a color in the area below the curve
    hue='Species',          # color colded on Species categorial
)
# Out:
# <Axes: xlabel='Petal Length (cm)', ylabel='Density'>

# %% [markdown]
# ## Summary of Plot Types
# ![plot_types](image/plot_types.png)

# %% [markdown]
# we've broken the chart types into three broad categories to help with this.
#
# * **Trend**s - A trend is defined as a pattern of change.
#   * `sns.lineplot` - **Line charts** are best to show trends over a period of time, and multiple lines can be used to show trends in more than one group.
#
# * **Relationship** - There are many different chart types that you can use to understand relationships between variables in your data.
#   * `sns.barplot` - **Bar charts** are useful for comparing quantities corresponding to different groups.
#   * `sns.heatmap` - **Heatmaps** can be used to find color-coded patterns in tables of numbers.
#   * `sns.scatterplot` - **Scatter plots** show the relationship between two continuous variables; if color-coded, we can also show the relationship with a third [categorical variable](https://en.wikipedia.org/wiki/Categorical_variable).
#   * `sns.regplot` - Including a **regression line** in the scatter plot makes it easier to see any linear relationship between two variables.
#   * `sns.lmplot` - This command is useful for drawing multiple regression lines, if the scatter plot contains multiple, color-coded groups.
#   * `sns.swarmplot` - **Categorical scatter plots** show the relationship between a continuous variable and a categorical variable.
#
# * **Distribution** - We visualize distributions to show the possible values that we can expect to see in a variable, along with how likely they are.
#   * `sns.histplot` - **Histograms** show the distribution of a single numerical variable.
#   * `sns.kdeplot` - **KDE plots** (or **2D KDE plots**) show an estimated, smooth distribution of a single numerical variable (or two numerical variables).
#   * `sns.jointplot` - This command is useful for simultaneously displaying a 2D KDE plot with the corresponding KDE plots for each individual variable.
